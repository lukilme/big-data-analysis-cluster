# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, year, to_date
import matplotlib.pyplot as plt

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

spark = SparkSession.builder.master("local[*]").appName("DataWarehouseVendas").getOrCreate()

df_vendedores = spark.read.option("header", True).csv("data/Vendedores.csv")
df_transportadoras = spark.read.option("header", True).csv("data/Transportadoras.csv")
df_fornecedores = spark.read.option("header", True).csv("data/Fornecedores.csv")
df_vendas = spark.read.option("header", True).csv("data/Vendas Globais.csv")

from pyspark.sql.types import DoubleType, IntegerType, DateType

df_vendas = df_vendas.withColumn("Vendas Custo", col("Vendas Custo").cast(DoubleType())) \
                     .withColumn("Margem Bruta", col("Margem Bruta").cast(DoubleType())) \
                     .withColumn("Vendas", col("Vendas").cast(DoubleType())) \
                     .withColumn("Desconto", col("Desconto").cast(DoubleType())) \
                     .withColumn("Frete", col("Frete").cast(DoubleType())) \
                     .withColumn("Qtde", col("Qtde").cast(IntegerType())) \
                     .withColumn("PedidoID", col("PedidoID").cast(IntegerType()))

df_vendas = df_vendas.withColumn("VendedorID", col("VendedorID").cast(IntegerType())) \
                     .withColumn("TransportadoraID", col("TransportadoraID").cast(IntegerType())) \
                     .withColumn("FornecedorID", col("FornecedorID").cast(IntegerType()))

dim_vendedores = df_vendedores.dropDuplicates(["VendedorID"])
dim_transportadoras = df_transportadoras.dropDuplicates(["TransportadoraID"])
dim_fornecedores = df_fornecedores.dropDuplicates(["FornecedorID"])

dim_clientes = df_vendas.select("ClienteID", "ClienteNome", "ClienteContato", "ClienteCidade", "ClientePaísID", "ClientePaís").dropDuplicates(["ClienteID"])
dim_produtos = df_vendas.select("ProdutoID", "ProdutoNome", "CategoriaID").dropDuplicates(["ProdutoID"])
dim_categorias = df_vendas.select("CategoriaID", "CategoriaNome", "CategoriaDescrição").dropDuplicates(["CategoriaID"])

fato_vendas = df_vendas.select(
    "PedidoID", "Data", "VendedorID", "TransportadoraID", "FornecedorID", "ClienteID", "ProdutoID",
    "Vendas Custo", "Margem Bruta", "Vendas", "Desconto", "Frete", "Qtde"
)
print(color.BOLD+"Vendedores:"+color.END)
print(dim_vendedores)
print(color.BOLD+"Transportadora:"+color.END)
print(dim_transportadoras)
print(color.BOLD+"Fornecedores:"+color.END)
print(dim_fornecedores)
print(color.BOLD+"Clientes:"+color.END)
print(dim_clientes)
print(color.BOLD+"Produtos:"+color.END)
print(dim_produtos)
print(color.BOLD+"Categorias:"+color.END)
print(dim_categorias)
print(color.BOLD+"Vendas:"+color.END)
print(fato_vendas)
# Out:
# Vendedores:
# DataFrame[VendedorID: string, VendedorNome: string]
# Transportadora:
# DataFrame[TransportadoraID: string, TransportadoraNome: string]
# Fornecedores:
# DataFrame[FornecedorID: string, FornecedorNome: string]
# Clientes:
# DataFrame[ClienteID: string, ClienteNome: string, ClienteContato: string, ClienteCidade: string, ClientePaísID: string, ClientePaís: string]
# Produtos:
# DataFrame[ProdutoID: string, ProdutoNome: string, CategoriaID: string]
# Categorias:
# DataFrame[CategoriaID: string, CategoriaNome: string, CategoriaDescrição: string]
# Vendas:
# DataFrame[PedidoID: int, Data: string, VendedorID: int, TransportadoraID: int, FornecedorID: int, ClienteID: string, ProdutoID: string, Vendas Custo: double, Margem Bruta: double, Vendas: double, Desconto: double, Frete: double, Qtde: int]

# %%
#1. Quem são os meus 10 maiores clientes, em termos de vendas ($)?
top_ten = fato_vendas.join(dim_clientes, "ClienteID") \
    .groupBy("ClienteID","ClienteNome") \
    .sum("Vendas") \
    .orderBy("sum(Vendas)", ascending=False) \
    .limit(10) \
    .toPandas()

print(top_ten)
fig, ax = plt.subplots()
ax.barh(top_ten['ClienteNome'], top_ten['sum(Vendas)'])
ax.invert_yaxis()  
ax.set_xlabel('Vendas ($)')
ax.set_title('Top 10 Clientes por Vendas')
plt.tight_layout()
plt.show()
# Out:
#   ClienteID       ClienteNome  sum(Vendas)
# 0        63         Grunewald  201320.4531
# 1        19        Th Fashing  152114.7892
# 2        37           Boleros  131133.1451
# 3        23           Champes   91362.1350
# 4        32  The Corner Store   82519.8235
# 5         1       Eintrach GS   75153.5245
# 6        80         Don Balón   68265.6625
# 7        44           Warp AG   65815.9770
# 8        73       Rode & Vite   59976.9277
# 9        79        Boombastic   50922.4655

# %%
#2. Quais os três maiores países, em termos de vendas ($)?
top_countries = fato_vendas.join(dim_clientes, "ClienteID") \
    .groupBy("ClientePaís") \
    .sum("Vendas") \
    .orderBy("sum(Vendas)", ascending=False) \
    .limit(3) \
    .toPandas()

fig, ax = plt.subplots()
ax.pie(
    top_countries['sum(Vendas)'],
    labels=top_countries['ClientePaís'],
    autopct='%1.1f%%',
    startangle=90
)
top_countries = fato_vendas.join(dim_clientes, "ClienteID") \
    .groupBy("ClientePaís") \
    .sum("Vendas") \
    .orderBy("sum(Vendas)", ascending=False) \
    .limit(10) \
    .toPandas()
print(top_countries)
ax.set_title('Participação dos 3 Maiores Países em Vendas')
ax.axis('equal') 
plt.show()
# Out:
#   ClientePaís  sum(Vendas)
# 0     Germany  519553.7336
# 1         USA  186313.2205
# 2      France  175565.3015
# 3          UK  167101.3462
# 4     Ireland  131133.1451
# 5      Brazil  120402.8175
# 6      Mexico   87158.3045
# 7   Venezuela   68258.6435
# 8     Denmark   59976.9277
# 9      Sweden   57162.0125

# %%
#3. Quais as categorias de produtos que geram maior faturamento (vendas $) no Brasil?

fato_vendas1 = fato_vendas.withColumn("Faturamento", expr("Vendas - Desconto + Frete"))
best_product = fato_vendas1.join(dim_clientes, "ClienteID") \
    .join(dim_produtos, "ProdutoID") \
    .join(dim_categorias, "CategoriaID") \
    .filter(col("ClientePaís") == "Brazil") \
    .groupBy("CategoriaID","CategoriaNome") \
    .sum("Faturamento") \
    .orderBy("sum(Faturamento)", ascending=False) \
    .toPandas()
print(best_product)
fig, ax = plt.subplots()
ax.bar(best_product['CategoriaNome'], best_product['sum(Faturamento)'], color='gold')
ax.set_xlabel('Categoria')
ax.set_ylabel('Vendas ($)')
ax.set_title('Faturamento por Categoria no Brasil')
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
#   CategoriaID    CategoriaNome  sum(Faturamento)
# 0           2      Womens wear          60190.75
# 1           3        Sportwear          20150.31
# 2           8         Babywear          11536.04
# 3           6   Men´s Footwear           9276.97
# 4           5  Ladies´Footwear           7612.14
# 5           1    Men´s Clothes           6807.11
# 6           4     Bath Clothes           3932.26
# 7           7  Children´s wear           2672.68

# %%
#3 alternativo
#3. Quais as categorias de produtos que geram maior faturamento (vendas $) no Brasil?

best_product = fato_vendas.join(dim_clientes, "ClienteID") \
    .join(dim_produtos, "ProdutoID") \
    .join(dim_categorias, "CategoriaID") \
    .filter(col("ClientePaís") == "Brazil") \
    .groupBy("CategoriaID","CategoriaNome") \
    .sum("Vendas") \
    .orderBy("sum(Vendas)", ascending=False) \
    .toPandas()
print(best_product)
fig, ax = plt.subplots()
ax.bar(best_product['CategoriaNome'], best_product['sum(Vendas)'], color='gold')
ax.set_xlabel('Categoria')
ax.set_ylabel('Vendas ($)')
ax.set_title('Faturamento por Categoria no Brasil')
plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
#   CategoriaID    CategoriaNome  sum(Vendas)
# 0           2      Womens wear   60941.7265
# 1           3        Sportwear   19509.4255
# 2           8         Babywear   10367.2100
# 3           6   Men´s Footwear    9467.7425
# 4           5  Ladies´Footwear    7798.5190
# 5           1    Men´s Clothes    6158.0640
# 6           4     Bath Clothes    3407.7050
# 7           7  Children´s wear    2752.4250

# %%
#4. Qual a despesa com frete envolvendo cada transportadora?
transport_tax = fato_vendas.join(dim_transportadoras, "TransportadoraID") \
    .groupBy("TransportadoraID","TransportadoraNome") \
    .sum("Frete") \
    .orderBy("sum(Frete)", ascending=False) \
    .toPandas()

fig, ax = plt.subplots()
ax.barh(
    transport_tax['TransportadoraNome'],
    transport_tax['sum(Frete)']
)
print(transport_tax)
ax.invert_yaxis()
ax.set_xlabel('Frete Total ($)')
ax.set_title('Despesa com Frete por Transportadora')
plt.tight_layout()
plt.show()
# Out:
#    TransportadoraID TransportadoraNome  sum(Frete)
# 0                 2     Global Express    70897.82
# 1                 1   General Shipping    19843.83
# 2                 3    Great Logistics    18771.69

# %%
#5. Quais são os principais clientes (vendas $) do segmento “Calçados Masculinos”
#(Men ́s Footwear) na Alemanha?
male_princess_foot = fato_vendas.join(dim_clientes, "ClienteID") \
    .join(dim_produtos, "ProdutoID") \
    .join(dim_categorias, "CategoriaID") \
    .filter((col("CategoriaNome") == "Men´s Footwear") & (col("ClientePaís") == "Germany")) \
    .groupBy("ClienteID","ClienteNome") \
    .sum("Vendas") \
    .orderBy("sum(Vendas)", ascending=False) \
    .toPandas()
print(male_princess_foot)

fig, ax = plt.subplots()
ax.barh(
    male_princess_foot['ClienteNome'],
    male_princess_foot['sum(Vendas)']
)
ax.invert_yaxis()
ax.set_xlabel('Vendas ($)')
ax.set_title("Top Clientes de Men´s Footwear na Alemanha")
plt.tight_layout()
plt.show()
# Out:
#   ClienteID         ClienteNome  sum(Vendas)
# 0        63           Grunewald   20488.4850
# 1        17         Gluderstedt   11923.3485
# 2        79          Boombastic   11235.9700
# 3         1         Eintrach GS   10377.8330
# 4        44             Warp AG    9085.7650
# 5        39    Noch Einmal GMBH    3030.7200
# 6        56     Casual Clothing    2602.5025
# 7        25          Halle Köln    1692.5580
# 8         6         Man Kleider    1108.0000
# 9        52  Kohl Industries AG     286.5600

# %%
#6. Quais os vendedores que mais dão descontos nos Estados Unidos?
low_tax_eua = fato_vendas.join(dim_clientes, "ClienteID") \
    .join(dim_vendedores, "VendedorID") \
    .filter(col("ClientePaís") == "USA") \
    .groupBy("VendedorID","VendedorNome") \
    .sum("Desconto") \
    .orderBy("sum(Desconto)", ascending=False) \
    .toPandas()

fig, ax = plt.subplots()
print(low_tax_eua)
ax.barh(
    low_tax_eua['VendedorNome'],
    low_tax_eua['sum(Desconto)']
)
ax.invert_yaxis()
ax.set_xlabel('Total de Descontos ($)')
ax.set_title('Vendedores com Maiores Descontos nos USA')
plt.tight_layout()
plt.show()
# Out:
#    VendedorID    VendedorNome  sum(Desconto)
# 0           1    Gael Monfils      7415.1295
# 1           3  Yannick Sinner      1160.0540
# 2           2  Martina Hingis       733.7770
# 3           9      Cori Gauff       404.5500

# %%
#7. Quais os fornecedores que dão a maior margem de lucro ($) no segmento de
#“Vestuário Feminino” (Womens wear)?
total_gain = fato_vendas.join(dim_produtos, "ProdutoID") \
    .join(dim_fornecedores, "FornecedorID") \
    .join(dim_categorias, "CategoriaID") \
    .filter(col("CategoriaNome") == "Womens wear") \
    .groupBy("FornecedorID","FornecedorNome") \
    .sum("Margem Bruta") \
    .orderBy("sum(Margem Bruta)", ascending=False) \
    .toPandas()
print(total_gain)
plt.figure(figsize=(14, 6))  

total_gain.plot.bar(
    x='FornecedorNome',
    y='sum(Margem Bruta)',
    color='red',
    legend=False
)

plt.xlabel('Fornecedor')
plt.ylabel('Margem Bruta Total ($)')
plt.title("Margem Bruta por Fornecedor em Women's Wear")
plt.xticks(rotation=45)  
plt.tight_layout() 
plt.show()
# Out:
#     FornecedorID  FornecedorNome  sum(Margem Bruta)
# 0             23   Pälsii Sports         81839.9408
# 1             18      Baby Dress         20675.2166
# 2             20  Wills Surfwear         10019.1193
# 3             24  Great Outdoors          9165.0332
# 4              2   Global Outlet          4884.9949
# 5             16     L.A. Sports          2304.5883
# 6             12     Luis Vilton          2192.3847
# 7              7    Tennis Place          1845.2659
# 8              3        Netshoes          1810.7737
# 9              1       USA Jeans          1273.9987
# 10             6       Surf Trip           147.6087

# %%
#8. Quanto que foi vendido ($) no ano de 2009? Analisando as vendas anuais entre 2009
#e 2012, podemos concluir que o faturamento vem crescendo, se mantendo estável ou
#decaindo?

df_vendas = df_vendas.withColumn("Data", to_date(col("Data"), "dd/MM/yyyy"))

fato_vendas_with_year = df_vendas.withColumn("Ano", year(col("Data")))

vendas_2009 = fato_vendas_with_year.filter(col("Ano") == 2009) \
    .agg({"Vendas": "sum"}) \
    .collect()[0][0]
print(vendas_2009)

year_sold = fato_vendas_with_year.filter((col("Ano") >= 2009) & (col("Ano") <= 2012)) \
    .groupBy("Ano") \
    .sum("Vendas") \
    .orderBy("Ano") \
    .toPandas()



plt.figure(figsize=(10, 5))
plt.plot(year_sold['Ano'], year_sold['sum(Vendas)'], 
         marker='o', linestyle='--', linewidth=2, markersize=8, color='navy')

for i, (ano, venda) in enumerate(zip(year_sold['Ano'], year_sold['sum(Vendas)'])):
    plt.text(ano, venda, f"${venda:,.0f}", 
             ha='center', va='bottom', fontsize=9)

plt.xlabel('Ano', fontsize=12)
plt.ylabel('Vendas ($)', fontsize=12)
plt.title('Evolução Anual de Vendas (2009-2012)', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(year_sold['Ano'])
plt.tight_layout()
plt.show()

print(f"Total vendido em 2009: ${vendas_2009:,.2f}")

for i in range(1, len(year_sold)):
    crescimento = ((year_sold['sum(Vendas)'].iloc[i] - year_sold['sum(Vendas)'].iloc[i-1]) / 
                 year_sold['sum(Vendas)'].iloc[i-1]) * 100
    print(f"Crescimento {year_sold['Ano'].iloc[i-1]}-{year_sold['Ano'].iloc[i]}: {crescimento:+.2f}%")
# Out:
# 87666.29400000005
# Total vendido em 2009: $87,666.29
# Crescimento 2009-2010: +322.95%
# Crescimento 2010-2011: +73.07%
# Crescimento 2011-2012: +6.43%

# %%
#10. Quais os países nos quais mais se tiram pedidos (qtde total de pedidos)?
wish_top_contries = fato_vendas.join(dim_clientes, "ClienteID") \
    .groupBy("ClientePaísID","ClientePaís") \
    .count() \
    .orderBy("count", ascending=False) \
    .toPandas()

top_orders = wish_top_contries.head(10)
print(top_orders)
fig, ax = plt.subplots()
ax.barh(
    top_orders['ClientePaís'],
    top_orders['count']
)
ax.invert_yaxis()
ax.set_xlabel('Número de Pedidos')
ax.set_title('Top 10 Países por Qtde de Pedidos')
plt.tight_layout()
plt.show()
# Out:
#   ClientePaísID ClientePaís  count
# 0           DEU     Germany    491
# 1           USA         USA    267
# 2           FRA      France    177
# 3           GBR          UK    163
# 4           BRA      Brazil    157
# 5           IRL     Ireland    140
# 6           VEN   Venezuela    121
# 7           MEX      Mexico    113
# 8           DNK     Denmark     92
# 9           CAN      Canada     87

# %%
formatos_data = [
    "dd/MM/yyyy",
    "MM/dd/yyyy",  
    "yyyy-MM-dd",   
    "dd-MM-yyyy"  
]

for formato in formatos_data:
    try:
        df_vendas = df_vendas.withColumn("Data", to_date(col("Data"), formato))
        if df_vendas.filter(col("Data").isNotNull()).count() > 0:
            print(f"check mate {formato}")
            break
    except:
        continue
else:
    print("negativo")
# Out:
# check mate dd/MM/yyyy
